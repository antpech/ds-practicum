# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Импорт" data-toc-modified-id="Импорт-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Импорт</a></span></li><li><span><a href="#Загрузим-данные" data-toc-modified-id="Загрузим-данные-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Загрузим данные</a></span></li><li><span><a href="#Обработка-данных" data-toc-modified-id="Обработка-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Обработка данных</a></span><ul class="toc-item"><li><span><a href="#Переименуем-столбцы" data-toc-modified-id="Переименуем-столбцы-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Переименуем столбцы</a></span></li><li><span><a href="#Сравним-столбцы-в-обучающей-и-тестовых-выборках" data-toc-modified-id="Сравним-столбцы-в-обучающей-и-тестовых-выборках-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Сравним столбцы в обучающей и тестовых выборках</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-1.3.2.1"><span class="toc-item-num">1.3.2.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Заполним-пропуски" data-toc-modified-id="Заполним-пропуски-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>Заполним пропуски</a></span></li></ul></li><li><span><a href="#Проверим-правильность-расчета-эффективности-обогощения" data-toc-modified-id="Проверим-правильность-расчета-эффективности-обогощения-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Проверим правильность расчета эффективности обогощения</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Проверим-аномальные-значение-в-целевых-показателях" data-toc-modified-id="Проверим-аномальные-значение-в-целевых-показателях-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Проверим аномальные значение в целевых показателях</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Исследуем-изменение-концентрации-элементов-на-каждом-этапе" data-toc-modified-id="Исследуем-изменение-концентрации-элементов-на-каждом-этапе-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Исследуем изменение концентрации элементов на каждом этапе</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Проанализируем-размер-гранул-на-каждом-этапе-в-выборках" data-toc-modified-id="Проанализируем-размер-гранул-на-каждом-этапе-в-выборках-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Проанализируем размер гранул на каждом этапе в выборках</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Исследуем-суммарные-концентрации-металлов-на-разных-стадиях" data-toc-modified-id="Исследуем-суммарные-концентрации-металлов-на-разных-стадиях-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Исследуем суммарные концентрации металлов на разных стадиях</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Функция-sMAPE" data-toc-modified-id="Функция-sMAPE-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Функция sMAPE</a></span></li><li><span><a href="#Подготовим-выборки-для-моделей" data-toc-modified-id="Подготовим-выборки-для-моделей-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Подготовим выборки для моделей</a></span></li><li><span><a href="#Обучение-и-сравнение-моделей" data-toc-modified-id="Обучение-и-сравнение-моделей-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Обучение и сравнение моделей</a></span></li><li><span><a href="#rougher_output_recovery" data-toc-modified-id="rougher_output_recovery-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>rougher_output_recovery</a></span><ul class="toc-item"><li><span><a href="#DummyRegressor" data-toc-modified-id="DummyRegressor-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>DummyRegressor</a></span></li><li><span><a href="#LinearRegression" data-toc-modified-id="LinearRegression-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>LinearRegression</a></span></li><li><span><a href="#DescisionTree" data-toc-modified-id="DescisionTree-3.4.3"><span class="toc-item-num">3.4.3&nbsp;&nbsp;</span>DescisionTree</a></span></li><li><span><a href="#RandomForest" data-toc-modified-id="RandomForest-3.4.4"><span class="toc-item-num">3.4.4&nbsp;&nbsp;</span>RandomForest</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.4.5"><span class="toc-item-num">3.4.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#final_output_recovery" data-toc-modified-id="final_output_recovery-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>final_output_recovery</a></span><ul class="toc-item"><li><span><a href="#DummyRegressor" data-toc-modified-id="DummyRegressor-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>DummyRegressor</a></span></li><li><span><a href="#LinearRegression" data-toc-modified-id="LinearRegression-3.5.2"><span class="toc-item-num">3.5.2&nbsp;&nbsp;</span>LinearRegression</a></span></li><li><span><a href="#DescisionTree" data-toc-modified-id="DescisionTree-3.5.3"><span class="toc-item-num">3.5.3&nbsp;&nbsp;</span>DescisionTree</a></span></li><li><span><a href="#RandomForest" data-toc-modified-id="RandomForest-3.5.4"><span class="toc-item-num">3.5.4&nbsp;&nbsp;</span>RandomForest</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.5.5"><span class="toc-item-num">3.5.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li></ul></li><li><span><a href="#Тестовые-данные" data-toc-modified-id="Тестовые-данные-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестовые данные</a></span><ul class="toc-item"><li><span><a href="#Dummy" data-toc-modified-id="Dummy-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Dummy</a></span></li><li><span><a href="#RandomForestRegressor" data-toc-modified-id="RandomForestRegressor-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>RandomForestRegressor</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Выводы</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Для горнодобывающего предприятиния необходиомо подготовить модель машинного обучения. Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Необходимо:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.

# %% [markdown]
# # Описание данных
#
# **Технологический процесс**
#
# - Rougher feed — исходное сырье
# - Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
# - Xanthate — ксантогенат (промотер, или активатор флотации);
# - Sulphate — сульфат (на данном производстве сульфид натрия);
# - Depressant — депрессант (силикат натрия).
# - Rougher process (англ. «грубый процесс») — флотация
# - Rougher tails — отвальные хвосты
# - Float banks — флотационная установка
# - Cleaner process — очистка
# - Rougher Au — черновой концентрат золота
# - Final Au — финальный концентрат золота
#
# **Параметры этапов**
# - air amount — объём воздуха
# - fluid levels — уровень жидкости
# - feed size — размер гранул сырья
# - feed rate — скорость подачи
#
# **Наименование признаков**
#
# Наименование признаков должно быть такое:
#
# [этап].[тип_параметра].[название_параметра]
#
# Пример: rougher.input.feed_ag
#
# Возможные значения для блока [этап]:
# - rougher — флотация
# - primary_cleaner — первичная очистка
# - secondary_cleaner — вторичная очистка
# - final — финальные характеристики
#
#
# Возможные значения для блока [тип_параметра]:
# - input — параметры сырья
# - output — параметры продукта
# - state — параметры, характеризующие текущее состояние этапа
# - calculation — расчётные характеристики

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Импорт

# %%
import pandas as pd
import numpy as np
from scipy import stats as st
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, cross_val_score, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LinearRegression
from sklearn.dummy import DummyRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

from sklearn.metrics import mean_absolute_error, make_scorer

# %%
pd.set_option('max_columns', None)

# %%
RANDOM_STATE = 12345

# %% [markdown]
# ### Загрузим данные

# %%
data_train = pd.read_csv('/datasets/gold_industry_train.csv', index_col='date')
data_test = pd.read_csv('/datasets/gold_industry_test.csv', index_col='date')
data_full = pd.read_csv('/datasets/gold_industry_full.csv', index_col='date')

# %%
data_train.sort_index(inplace=True)
data_test.sort_index(inplace=True)
data_full.sort_index(inplace=True)

# %%
def data_info(df):
    display(df.info())
    display(df.head())
    df_na = pd.DataFrame(df.isna().sum())
    df_na.columns = ['count_na']
    df_na['prc'] = df_na['count_na'] / df.shape[0] * 100
    print('')
    print('Проверим пустые значения:')
    display(df_na[df_na['count_na'] > 0])

# %%
data_info(data_train)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14579 entries, 2016-01-15 00:00:00 to 2017-12-09 13:59:59
# Data columns (total 86 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   rougher.input.feed_au                               14579 non-null  float64
#  1   rougher.input.feed_ag                               14579 non-null  float64
#  2   rougher.input.feed_pb                               14507 non-null  float64
#  3   rougher.input.feed_sol                              14502 non-null  float64
#  4   rougher.input.feed_rate                             14572 non-null  float64
#  5   rougher.input.feed_size                             14478 non-null  float64
#  6   rougher.input.floatbank10_sulfate                   14548 non-null  float64
#  7   rougher.input.floatbank10_xanthate                  14572 non-null  float64
# ...

# %%
data_info(data_test)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4860 entries, 2017-12-09 14:59:59 to 2018-08-18 10:59:59
# Data columns (total 52 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   rougher.input.feed_au                       4860 non-null   float64
#  1   rougher.input.feed_ag                       4860 non-null   float64
#  2   rougher.input.feed_pb                       4832 non-null   float64
#  3   rougher.input.feed_sol                      4838 non-null   float64
#  4   rougher.input.feed_rate                     4856 non-null   float64
#  5   rougher.input.feed_size                     4816 non-null   float64
#  6   rougher.input.floatbank10_sulfate           4857 non-null   float64
#  7   rougher.input.floatbank10_xanthate          4859 non-null   float64
#  8   rougher.state.floatbank10_a_air             4859 non-null   float64
# ...

# %%
data_info(data_full)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19439 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 86 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   rougher.input.feed_au                               19439 non-null  float64
#  1   rougher.input.feed_ag                               19439 non-null  float64
#  2   rougher.input.feed_pb                               19339 non-null  float64
#  3   rougher.input.feed_sol                              19340 non-null  float64
#  4   rougher.input.feed_rate                             19428 non-null  float64
#  5   rougher.input.feed_size                             19294 non-null  float64
#  6   rougher.input.floatbank10_sulfate                   19405 non-null  float64
#  7   rougher.input.floatbank10_xanthate                  19431 non-null  float64
# ...

# %% [markdown]
# В полной выборке `data_full` присутствуют все столбцы для тестовой выборки

# %% [markdown]
# ### Обработка данных

# %% [markdown]
# #### Переименуем столбцы
#
# Для избежания ошибок с точками в названиях

# %%
def data_columns_rename(df):
    df.rename(str.lower, axis='columns')

    cols = {}
    for col in df.columns:
        cols[col] = col.replace(".", "_")

    df.rename(columns=cols, inplace=True)

# %%
data_columns_rename(data_train)
data_columns_rename(data_test)
data_columns_rename(data_full)

# %% [markdown]
# #### Сравним столбцы в обучающей и тестовых выборках

# %%
set_train_columns = set(data_train.columns)
set_test_columns = set(data_test.columns)
columns_difference = list(set_train_columns.difference(set_test_columns))
columns_difference
# Out:
# ['rougher_output_recovery',
#  'primary_cleaner_output_concentrate_sol',
#  'secondary_cleaner_output_tail_ag',
#  'final_output_concentrate_au',
#  'rougher_output_concentrate_ag',
#  'rougher_calculation_floatbank11_sulfate_to_au_feed',
#  'rougher_calculation_sulfate_to_au_concentrate',
#  'secondary_cleaner_output_tail_pb',
#  'primary_cleaner_output_tail_sol',
#  'rougher_output_tail_sol',
#  'secondary_cleaner_output_tail_au',
#  'rougher_output_tail_ag',
#  'primary_cleaner_output_tail_pb',
#  'rougher_calculation_au_pb_ratio',
#  'final_output_tail_au',
#  'secondary_cleaner_output_tail_sol',
#  'primary_cleaner_output_tail_au',
#  'primary_cleaner_output_concentrate_au',
#  'rougher_output_concentrate_au',
#  'primary_cleaner_output_concentrate_pb',
#  'rougher_output_tail_au',
#  'rougher_output_tail_pb',
#  'primary_cleaner_output_concentrate_ag',
#  'final_output_concentrate_pb',
#  'final_output_tail_pb',
#  'final_output_concentrate_ag',
# ...

# %% [markdown]
# ##### Выводы
#
# - В тестовой выборке отсутствую целевые значения. Добавим их из full
# - По всей видимости данные параметры не доступны сразу.
# - Для расчета целевого параметра и построения модели необходимо использовать только столбцы из тестовой выборки.
# - Но данные столбцы и значения могут пригодиться для проверки модели.

# %%
data_test = pd.merge(data_test, data_full[['rougher_output_recovery', 'final_output_recovery']], left_index=True, right_index=True)

# %%
data_test.head()
# Out:
#                      rougher_input_feed_au  rougher_input_feed_ag  \
# date
# 2017-12-09 14:59:59               4.365491               6.158718
# 2017-12-09 15:59:59               4.362781               6.048130
# 2017-12-09 16:59:59               5.081681               6.082745
# 2017-12-09 17:59:59               5.145949               6.084374
# 2017-12-09 18:59:59               5.735249               6.165220
#
#                      rougher_input_feed_pb  rougher_input_feed_sol  \
# date
# 2017-12-09 14:59:59               3.875727               39.135119
# 2017-12-09 15:59:59               3.902537               39.713906
# 2017-12-09 16:59:59               4.564078               37.208683
# 2017-12-09 17:59:59               4.768124               36.808874
# 2017-12-09 18:59:59               4.512346               37.810642
#
#                      rougher_input_feed_rate  rougher_input_feed_size  \
# date
# 2017-12-09 14:59:59               555.820208                94.544358
# ...

# %% [markdown]
# #### Заполним пропуски
#
# Удалим строки с пропусками в целевых признаках

# %%
def data_dropna(df):
    df.dropna(subset = ['rougher_output_recovery', 'final_output_recovery'], inplace=True)

# %%
data_dropna(data_train)
data_dropna(data_test)
data_dropna(data_full)

# %% [markdown]
# В задании указано, что соседние по времени параметры часто похожи, по этому можно заполнить средним значением между предыдущим и последующим измерениями. Воспользуемся методом `interpolate`

# %%
data_train.interpolate(inplace=True)
data_test.interpolate(inplace=True)
data_full.interpolate(inplace=True)

# %%
data_info(data_test)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4860 entries, 2017-12-09 14:59:59 to 2018-08-18 10:59:59
# Data columns (total 54 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   rougher_input_feed_au                       4860 non-null   float64
#  1   rougher_input_feed_ag                       4860 non-null   float64
#  2   rougher_input_feed_pb                       4860 non-null   float64
#  3   rougher_input_feed_sol                      4860 non-null   float64
#  4   rougher_input_feed_rate                     4860 non-null   float64
#  5   rougher_input_feed_size                     4860 non-null   float64
#  6   rougher_input_floatbank10_sulfate           4860 non-null   float64
#  7   rougher_input_floatbank10_xanthate          4860 non-null   float64
#  8   rougher_state_floatbank10_a_air             4860 non-null   float64
# ...

# %% [markdown]
# ### Проверим правильность расчета эффективности обогощения

# %% [markdown]
# Формула:
#
# Recovery = (C * (F-T)) / (F * (C-T)) * 100
#
# где:
# - C — доля золота в концентрате после флотации/очистки; (rougher.output.concentrate_au)
# - F — доля золота в сырье/концентрате до флотации/очистки; (rougher.input.feed_au)
# - T — доля золота в отвальных хвостах после флотации/очистки. (rougher.output.tail_au)

# %%
data_train['rougher_output_recovery_calc'] = (data_train['rougher_output_concentrate_au'] * (data_train['rougher_input_feed_au'] - data_train['rougher_output_tail_au'])) / (data_train['rougher_input_feed_au'] * (data_train['rougher_output_concentrate_au'] - data_train['rougher_output_tail_au'])) * 100

# %% [markdown]
# **Сравним полученные значения**

# %%
data_train[['rougher_output_recovery', 'rougher_output_recovery_calc']]
# Out:
#                      rougher_output_recovery  rougher_output_recovery_calc
# date
# 2016-01-15 00:00:00                87.107763                     87.107763
# 2016-01-15 01:00:00                86.843261                     86.843261
# 2016-01-15 02:00:00                86.842308                     86.842308
# 2016-01-15 03:00:00                87.226430                     87.226430
# 2016-01-15 04:00:00                86.688794                     86.688794
# ...                                      ...                           ...
# 2017-12-09 09:59:59                87.684717                     87.684717
# 2017-12-09 10:59:59                90.677361                     90.677361
# 2017-12-09 11:59:59                89.574376                     89.574376
# 2017-12-09 12:59:59                87.724007                     87.724007
# 2017-12-09 13:59:59                88.890579                     88.890579
#
# [14579 rows x 2 columns]

# %% [markdown]
# **Посчитаем среднюю абсолютную ошибку `MAE` для выборок**

# %%
MAE = mean_absolute_error(data_train['rougher_output_recovery'], data_train['rougher_output_recovery_calc'])
print("MAE = ", MAE)
# Out:
# MAE =  9.83758577644259e-15

# %% [markdown]
# #### Вывод
#
# Значение средней абсолютной ошибки очень маленькое 9.83758577644259e-15. Значения посчитаны правильно.

# %% [markdown]
# ### Проверим аномальные значение в целевых показателях

# %%
print('Train')
display(data_train['rougher_output_recovery'].describe())
display(data_train['final_output_recovery'].describe())
# Out:
# Train
# count    14579.000000
# mean        82.521200
# std         15.797521
# min          0.000000
# 25%         80.558542
# 50%         85.946497
# 75%         89.960375
# max        100.000000
# Name: rougher_output_recovery, dtype: float64
# count    14579.000000
# mean        66.759066
# std         10.619709
# min          0.000000
# 25%         63.114596
# 50%         67.962788
# 75%         72.598187
# max        100.000000
# Name: final_output_recovery, dtype: float64

# %%
print('Test')
display(data_test['rougher_output_recovery'].describe())
display(data_test['final_output_recovery'].describe())
# Out:
# Test
# count    4860.000000
# mean       85.750584
# std         6.648023
# min        18.491446
# 25%        82.354512
# 50%        86.839027
# 75%        90.145117
# max       100.000000
# Name: rougher_output_recovery, dtype: float64
# count    4860.000000
# mean       67.923574
# std         8.414134
# min         5.586496
# 25%        63.939233
# 50%        68.744713
# 75%        73.037434
# max       100.000000
# Name: final_output_recovery, dtype: float64

# %%
def data_print_anomalies_count(df):
    print('Кол-во rougher_output_recovery = 0:', df[df['rougher_output_recovery'] == 0]['rougher_output_recovery'].count())
    print('Кол-во rougher_output_recovery >= 100:', df[df['rougher_output_recovery'] >= 100]['rougher_output_recovery'].count())
    print('Кол-во final_output_recovery = 0:', df[df['final_output_recovery'] == 0]['final_output_recovery'].count())
    print('Кол-во final_output_recovery >= 100:', df[df['final_output_recovery'] >= 100]['final_output_recovery'].count())

# %%
print('Train')
data_print_anomalies_count(data_train)
# Out:
# Train
# Кол-во rougher_output_recovery = 0: 394
# Кол-во rougher_output_recovery >= 100: 3
# Кол-во final_output_recovery = 0: 98
# Кол-во final_output_recovery >= 100: 72

# %%
print('Test')
data_print_anomalies_count(data_test)
# Out:
# Test
# Кол-во rougher_output_recovery = 0: 0
# Кол-во rougher_output_recovery >= 100: 2
# Кол-во final_output_recovery = 0: 0
# Кол-во final_output_recovery >= 100: 19

# %% [markdown]
# Удалим из обучающей выборки строки с целевыми значения = 0

# %%
data_train = data_train[data_train['rougher_output_recovery'] > 0]
data_train = data_train[data_train['final_output_recovery'] > 0]
#data_train = data_train[data_train['rougher_output_recovery'] < 100]
#data_train = data_train[data_train['final_output_recovery'] < 100]

# %%
print('Train')
data_print_anomalies_count(data_train)
# Out:
# Train
# Кол-во rougher_output_recovery = 0: 0
# Кол-во rougher_output_recovery >= 100: 3
# Кол-во final_output_recovery = 0: 0
# Кол-во final_output_recovery >= 100: 71

# %%
data_test = data_test[data_test['rougher_output_recovery'] > 0]
data_test = data_test[data_test['final_output_recovery'] > 0]
#data_test = data_test[data_test['rougher_output_recovery'] < 100]
#data_test = data_test[data_test['final_output_recovery'] < 100]

# %%
print('Test')
data_print_anomalies_count(data_test)
# Out:
# Test
# Кол-во rougher_output_recovery = 0: 0
# Кол-во rougher_output_recovery >= 100: 2
# Кол-во final_output_recovery = 0: 0
# Кол-во final_output_recovery >= 100: 19

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Исследуем изменение концентрации элементов на каждом этапе

# %%
au_cols = ['rougher_input_feed_au', 'rougher_output_concentrate_au', 'primary_cleaner_output_concentrate_au', 'final_output_concentrate_au']
ag_cols = ['rougher_input_feed_ag', 'rougher_output_concentrate_ag', 'primary_cleaner_output_concentrate_ag', 'final_output_concentrate_ag']
pb_cols = ['rougher_input_feed_pb', 'rougher_output_concentrate_pb', 'primary_cleaner_output_concentrate_pb', 'final_output_concentrate_pb']
sol_cols = ['rougher_input_feed_sol', 'rougher_output_concentrate_sol', 'primary_cleaner_output_concentrate_sol', 'final_output_concentrate_sol']

# %%
def data_plot_concentration(df, cols=[], title=''):

    cols1 = cols
    if len(cols) == 0:
        cols1 = list(df.columns)

    for i in range(len(cols1)):
        sns.kdeplot(df[cols1[i]], label=cols1[i])

# Plot formatting
    plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
    if title != '':
        plt.title(title)
    plt.xlabel('concentration')
    plt.ylabel('')

# %%
data_plot_concentration(data_train, au_cols, 'AU')

# %%
data_plot_concentration(data_train, ag_cols, 'AG')

# %%
data_plot_concentration(data_train, pb_cols, 'PB')

# %%
data_plot_concentration(data_train, sol_cols, 'SOL')

# %% [markdown]
# #### Вывод
#
# 1. Концентрации золота AU растет от стадии к стадии. На входе среднее значение около 8%, на выходе среднее значение концентрации золота около 45%
# 2. Концентрация серебра AG:
#     - увеличилась после флотации
#     - уменьшилась после очисток
#     - на входе средняя концентрация около 8%, на выходе упала до средней - 5%
# 3. Концентрация PB увеличилась после всех стадий обработки.
# 4. Среднее значение концентрация SOL сильно уменьшилась: с 40% до 9%

# %% [markdown]
# Видно, что золото растёт в концентрации - это здорово! А серебро падает - ведь наша цель -  золото, верно?)
# А свинец - это побочный элемент химических реакций, по этой причине немного и увеличивается его концентрация

# %% [markdown]
# ### Проанализируем размер гранул на каждом этапе в выборках

# %%
def data_plot_size(df, cols, title=''):
    print(title)
    for i in range(len(cols)):
        plt.subplot(1, 2, i+1)
        sns.kdeplot(df[cols[i]], label=cols[i])

        # Plot formatting
        plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
        plt.xlabel('size')
        plt.ylabel('')

# %%
sns.kdeplot(data_train['rougher_input_feed_size'], label='train')
sns.kdeplot(data_test['rougher_input_feed_size'], label='test')

# Plot formatting
plt.title('Распределение размеров гранул. rougher_input_feed_size')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.xlabel('size')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
sns.kdeplot(data_train['primary_cleaner_input_feed_size'], label='train')
sns.kdeplot(data_test['primary_cleaner_input_feed_size'], label='test')

# Plot formatting
plt.title('Распределение размеров гранул. primary_cleaner_input_feed_size')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.xlabel('size')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
data_train['rougher_input_feed_size'].describe()
# Out:
# count    14089.000000
# mean        58.968995
# std         23.019249
# min          0.049194
# 25%         47.235098
# 50%         54.448303
# 75%         64.421649
# max        484.967466
# Name: rougher_input_feed_size, dtype: float64

# %%
data_train['primary_cleaner_input_feed_size'].describe()
# Out:
# count    14089.000000
# mean         7.306959
# std          0.623024
# min          1.080000
# 25%          6.940000
# 50%          7.280000
# 75%          7.680000
# max         15.500000
# Name: primary_cleaner_input_feed_size, dtype: float64

# %% [markdown]
# #### Вывод
#
# 1. Распределение размеров гранул на обучающей и тестовой выборках совпадают
# 2. Средний размер гранул после флотации уменьшился с 58.92 до 7.3
# 3. Размер гранул после флотации стандартизировался. До флотации стандартное отклонение = 22, а после = 0.6
# 4. В обучающей выборке диапозон значений более широкий. Но с точностью нельзя сказать, что это аномалии. Оставим эти значения и обучим на более широком диапозоне.

# %% [markdown]
# ### Исследуем суммарные концентрации металлов на разных стадиях

# %%
def get_df_data_metals(df):
    data_metals = pd.DataFrame()
    data_metals['rougher_input_feed'] = df['rougher_input_feed_au'] + df['rougher_input_feed_ag'] + df['rougher_input_feed_pb']
    data_metals['rougher_output_concentrate'] = df['rougher_output_concentrate_au'] + df['rougher_output_concentrate_ag'] + df['rougher_output_concentrate_pb']
    data_metals['primary_cleaner_output_concentrate'] = df['primary_cleaner_output_concentrate_au'] + df['primary_cleaner_output_concentrate_ag'] + df['primary_cleaner_output_concentrate_pb']
    data_metals['final_output_concentrate'] = df['final_output_concentrate_au'] + df['final_output_concentrate_ag'] + df['final_output_concentrate_pb']
    return data_metals

# %%
data_metals = get_df_data_metals(data_train)

# %%
data_plot_concentration(data_metals, title='Изменение суммарной концентрации металлов')

# %%
data_metals['rougher_input_feed'].describe()
# Out:
# count    14089.000000
# mean        20.805481
# std          4.462023
# min          0.030000
# 25%         17.393624
# 50%         20.380774
# 75%         23.957954
# max         33.324268
# Name: rougher_input_feed, dtype: float64

# %%
data_metals['rougher_output_concentrate'].describe()
# Out:
# count    14089.000000
# mean        40.245349
# std          3.946688
# min          0.030000
# 25%         38.598876
# 50%         40.466147
# 75%         42.498346
# max         55.568687
# Name: rougher_output_concentrate, dtype: float64

# %%
data_metals['primary_cleaner_output_concentrate'].describe()
# Out:
# count    14089.000000
# mean        50.196049
# std          7.987088
# min          0.000000
# 25%         50.029507
# 50%         51.847495
# 75%         53.294679
# max         60.106566
# Name: primary_cleaner_output_concentrate, dtype: float64

# %%
data_metals['final_output_concentrate'].describe()
# Out:
# count    14089.000000
# mean        59.481691
# std          4.443370
# min          0.030000
# 25%         59.278089
# 50%         60.275026
# 75%         61.053101
# max         64.968881
# Name: final_output_concentrate, dtype: float64

# %%
rows = ((data_metals['rougher_input_feed'] <= 5)
        | (data_metals['rougher_output_concentrate'] <= 10)
        | (data_metals['primary_cleaner_output_concentrate'] <= 10)
        | (data_metals['final_output_concentrate'] <= 10))

print(f'строк к удалению: {len(data_metals.loc[rows]["rougher_input_feed"]) / len(data_metals) * 100}%')
# Out:
# строк к удалению: 1.7815316913904464%

# %%
data_train = data_train[data_train['rougher_input_feed_au'] + data_train['rougher_input_feed_ag'] + data_train['rougher_input_feed_pb'] > 5]
data_train = data_train[data_train['rougher_output_concentrate_au'] + data_train['rougher_output_concentrate_ag'] + data_train['rougher_output_concentrate_pb'] > 10]
data_train = data_train[data_train['primary_cleaner_output_concentrate_au'] + data_train['primary_cleaner_output_concentrate_ag'] + data_train['primary_cleaner_output_concentrate_pb'] > 10]
data_train = data_train[data_train['final_output_concentrate_au'] + data_train['final_output_concentrate_ag'] + data_train['final_output_concentrate_pb'] > 10]

# %% [markdown]
# #### Вывод
#
# 1. Концентрация металлов все время растет. От среднего 20.82% до 59%
# 2. Есть аномалии - около 0 концентрация металла в гранулах
# 3. Из данных отрезали длинные хвосты с аномалиями

# %% [markdown]
# ## Модель

# %% [markdown]
# ### Функция sMAPE

# %%
def sMAPE(target, predict):
    return np.sum(np.abs(target - predict) / ((np.abs(target) + np.abs(predict)) / 2)) / len(target) * 100

# %% [markdown]
# ### Подготовим выборки для моделей

# %%
rougher_cols = ['rougher_input_feed_au',
                'rougher_input_feed_ag',
                'rougher_input_feed_pb',
                'rougher_input_feed_sol',
                'rougher_input_feed_rate',
                'rougher_input_feed_size',
                'rougher_input_floatbank10_sulfate',
                'rougher_input_floatbank10_xanthate',
                'rougher_state_floatbank10_a_air',
                'rougher_state_floatbank10_a_level',
                'rougher_state_floatbank10_b_air',
                'rougher_state_floatbank10_b_level',
                'rougher_state_floatbank10_c_air',
                'rougher_state_floatbank10_c_level',
                'rougher_state_floatbank10_d_air',
                'rougher_state_floatbank10_d_level',
                'rougher_state_floatbank10_e_air',
                'rougher_state_floatbank10_e_level',
                'rougher_state_floatbank10_f_air',
                'rougher_state_floatbank10_f_level',
                'rougher_input_floatbank11_sulfate',
                'rougher_input_floatbank11_xanthate'
               ]

final_cols = data_test.drop(['rougher_output_recovery', 'final_output_recovery'], axis=1).columns

# %%
#train - будем смотреть кросс-валидацию
#test - финальный тест

#rougher
train_rougher_features = data_train[rougher_cols]
train_rougher_target = data_train['rougher_output_recovery']
test_rougher_features = data_test[rougher_cols]
test_rougher_target = data_test['rougher_output_recovery']

scaler = StandardScaler()
scaler.fit(train_rougher_features)
train_rougher_features = pd.DataFrame(scaler.transform(train_rougher_features), columns=rougher_cols)
test_rougher_features = pd.DataFrame(scaler.transform(test_rougher_features), columns=rougher_cols)

#final
train_final_features = data_train[final_cols]
train_final_target = data_train['final_output_recovery']
test_final_features = data_test[final_cols]
test_final_target = data_test['final_output_recovery']

scaler.fit(train_final_features[final_cols])
train_final_features = pd.DataFrame(scaler.transform(train_final_features), columns=final_cols)
test_final_features = pd.DataFrame(scaler.transform(test_final_features), columns=final_cols)

# %% [markdown]
# ### Обучение и сравнение моделей

# %%
def print_mean_score(scores):
    print(f'Средняя оценка качества модели: {np.mean(scores)}')

# %%
sMAPE_score = make_scorer(sMAPE, greater_is_better=False)

# %%
#подбор параметров
def get_best_estimator(model, params, scoring, features, target, cv, n_iter=100):
    RSCV = RandomizedSearchCV(estimator = model, param_distributions = params,
                        cv = cv, # количество разбиений на кросс-валидацию
                        scoring = scoring,
                        n_iter = n_iter
                       )
    RSCV.fit(features, target)
    print('scorer_:', RSCV.scorer_)
    print('best_score_:', RSCV.best_score_)
    print('best_params_:', RSCV.best_params_)
    print('best_estimator_', RSCV.best_estimator_)
    return RSCV.best_estimator_

# %% [markdown]
# ### rougher_output_recovery

# %% [markdown]
# #### DummyRegressor

# %%
# %%time

model = DummyRegressor()
model.fit(train_rougher_features, train_rougher_target)
sMAPE(train_rougher_target, model.predict(train_rougher_features))
# Out:
# CPU times: user 3.65 ms, sys: 0 ns, total: 3.65 ms
# Wall time: 3.53 ms
# 6.835345379145997

# %%
model =  DummyRegressor()
scores = cross_val_score(model, train_rougher_features, train_rougher_target, cv=50, scoring=sMAPE_score)
print_mean_score(scores*-1)
# Out:
# Средняя оценка качества модели: 6.914868983040794

# %% [markdown]
# #### LinearRegression

# %%
len(train_rougher_features)
# Out:
# 13838

# %%
# %%time

params = {"positive": [True, False],
          "fit_intercept": [True, False]
         }

model = get_best_estimator(LinearRegression() , params, sMAPE_score, train_rougher_features, train_rougher_target, cv=10)
print(f'sMAPE: {sMAPE(train_rougher_target, model.predict(train_rougher_features))}')
# Out:
# /opt/conda/lib/python3.9/site-packages/sklearn/model_selection/_search.py:285: UserWarning: The total space of parameters 4 is smaller than n_iter=100. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# scorer_: make_scorer(sMAPE, greater_is_better=False)
# best_score_: -5.728034486368456
# best_params_: {'positive': True, 'fit_intercept': True}
# best_estimator_ LinearRegression(positive=True)
# sMAPE: 5.0831056989918535
# CPU times: user 1.95 s, sys: 4.12 s, total: 6.07 s
# Wall time: 6.03 s

# %% [markdown]
# **Результат**
#
# - scorer_: make_scorer(sMAPE, greater_is_better=False)
# - best_score_: -5.769776586396304
# - best_params_: {'positive': True, 'fit_intercept': True}
# - best_estimator_ LinearRegression(positive=True)
# - sMAPE: 5.1507273256724335
# - CPU times: user 2.04 s, sys: 3.83 s, total: 5.87 s
# - Wall time: 5.79 s

# %%
model =  LinearRegression(positive=True)
scores = cross_val_score(model, train_rougher_features, train_rougher_target, cv=50, scoring=sMAPE_score)
print_mean_score(scores*-1)
# Out:
# Средняя оценка качества модели: 5.375291695422793

# %% [markdown]
# #### DescisionTree

# %%
# %%time

max_depth = [int(x) for x in np.linspace(5, 20, num = 5)]
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]
params = { 'max_depth': max_depth,
           'min_samples_split': min_samples_split,
           'min_samples_leaf': min_samples_leaf
         }

#model = get_best_estimator(DecisionTreeRegressor(), params, sMAPE_score, train_rougher_features, train_rougher_target, cv=10)
#print(f'sMAPE: {sMAPE(train_rougher_target, model.predict(train_rougher_features))}')
# Out:
# CPU times: user 93 µs, sys: 46 µs, total: 139 µs
# Wall time: 145 µs

# %% [markdown]
# **Результат**
#
# - scorer_: make_scorer(sMAPE, greater_is_better=False)
# - best_score_: -6.205356457782916
# - best_params_: {'min_samples_split': 5, 'min_samples_leaf': 1, 'max_depth': 5}
# - best_estimator_ DecisionTreeRegressor(max_depth=5, min_samples_split=5)
# - sMAPE: 4.394351446393299
# - CPU times: user 27.7 s, sys: 0 ns, total: 27.7 s
# - Wall time: 27.7 s

# %%
# %%time

model =  DecisionTreeRegressor(max_depth=5, min_samples_split=5)
#scores = cross_val_score(model, train_rougher_features, train_rougher_target, cv=50, scoring=sMAPE_score)
#print_mean_score(scores*-1)
# Out:
# CPU times: user 20 µs, sys: 9 µs, total: 29 µs
# Wall time: 31.5 µs

# %% [markdown]
# Средняя оценка качества модели: 5.433160174550952

# %% [markdown]
# #### RandomForest

# %%
# %%time

n_estimators = [int(x) for x in np.linspace(start = 20, stop = 100, num = 10)]
max_depth = [int(x) for x in np.linspace(5, 20, num = 5)]
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]
params = { 'n_estimators': n_estimators,
           'max_depth': max_depth,
           'min_samples_split': min_samples_split,
           'min_samples_leaf': min_samples_leaf
         }

#model = get_best_estimator(RandomForestRegressor(), params, sMAPE_score, train_rougher_features, train_rougher_target, cv=10)
#print(f'sMAPE: {sMAPE(train_rougher_target, model.predict(train_rougher_features))}')
# Out:
# CPU times: user 182 µs, sys: 90 µs, total: 272 µs
# Wall time: 238 µs

# %% [markdown]
# **Результат**
#
# - scorer_: make_scorer(sMAPE, greater_is_better=False)
# - best_score_: -5.861154821616412
# - best_params_: {'n_estimators': 37, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 12}
# - best_estimator_ RandomForestRegressor(max_depth=12, min_samples_leaf=4, n_estimators=37)
# - sMAPE: 2.282364639501214
# - CPU times: user 12min 55s, sys: 0 ns, total: 12min 55s
# - Wall time: 12min 57s

# %%
# %%time

model =  RandomForestRegressor(max_depth=12, min_samples_leaf=4, n_estimators=37)
#scores = cross_val_score(model, train_rougher_features, train_rougher_target, cv=50, scoring=sMAPE_score)
#print_mean_score(scores*-1)
# Out:
# CPU times: user 32 µs, sys: 16 µs, total: 48 µs
# Wall time: 50.1 µs

# %% [markdown]
# Средняя оценка качества модели: 4.933858923211307

# %% [markdown]
# #### Вывод
#
# Лучшая модель RandomForestRegressor(max_depth=12, min_samples_leaf=4, n_estimators=37)
#
# Средняя оценка качества модели: 4.933858923211307

# %% [markdown]
# ### final_output_recovery

# %% [markdown]
# #### DummyRegressor

# %%
# %%time

model = DummyRegressor()
model.fit(train_final_features, train_final_target)
sMAPE(train_final_target, model.predict(train_final_features))
# Out:
# CPU times: user 2.32 ms, sys: 0 ns, total: 2.32 ms
# Wall time: 2.09 ms
# 9.646355944701728

# %%
model =  DummyRegressor()
scores = cross_val_score(model, train_final_features, train_final_target, cv=50, scoring=sMAPE_score)
print_mean_score(scores*-1)
# Out:
# Средняя оценка качества модели: 9.708322877167637

# %% [markdown]
# #### LinearRegression

# %%
len(train_final_features)
# Out:
# 13838

# %%
# %%time

params = {"positive": [True, False],
          "fit_intercept": [True, False]
         }

model = get_best_estimator(LinearRegression() , params, sMAPE_score, train_final_features, train_final_target, cv=10)
print(f'sMAPE: {sMAPE(train_final_target, model.predict(train_final_features))}')
# Out:
# /opt/conda/lib/python3.9/site-packages/sklearn/model_selection/_search.py:285: UserWarning: The total space of parameters 4 is smaller than n_iter=100. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# scorer_: make_scorer(sMAPE, greater_is_better=False)
# best_score_: -8.999053404321012
# best_params_: {'positive': True, 'fit_intercept': True}
# best_estimator_ LinearRegression(positive=True)
# sMAPE: 8.09962372459472
# CPU times: user 4.56 s, sys: 9.5 s, total: 14.1 s
# Wall time: 14.1 s

# %% [markdown]
# **Результат**
#
# - scorer_: make_scorer(sMAPE, greater_is_better=False)
# - best_score_: 9.203623144716577
# - best_params_: {'positive': True, 'fit_intercept': True}
# - best_estimator_ LinearRegression(positive=True)
# - sMAPE: 8.290799346839724
# - CPU times: user 4.62 s, sys: 8.53 s, total: 13.2 s
# - Wall time: 13.1 s

# %%
# %%time

model =  LinearRegression(positive=True)
scores = cross_val_score(model, train_final_features, train_final_target, cv=50, scoring=sMAPE_score)
print_mean_score(scores*-1)
# Out:
# Средняя оценка качества модели: 8.525016776737411
# CPU times: user 4 s, sys: 5.43 s, total: 9.43 s
# Wall time: 9.43 s

# %% [markdown]
# #### DescisionTree

# %%
# %%time

max_depth = [int(x) for x in np.linspace(5, 20, num = 5)]
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]
params = { 'max_depth': max_depth,
           'min_samples_split': min_samples_split,
           'min_samples_leaf': min_samples_leaf
         }

#model = get_best_estimator(DecisionTreeRegressor(), params, sMAPE_score, train_final_features, train_final_target, cv=10)
#print(f'sMAPE: {sMAPE(train_final_target, model.predict(train_final_features))}')
# Out:
# CPU times: user 267 µs, sys: 157 µs, total: 424 µs
# Wall time: 146 µs

# %% [markdown]
# **Результат**
#
# - scorer_: make_scorer(sMAPE, greater_is_better=False)
# - best_score_: 10.133576035093564
# - best_params_: {'min_samples_split': 2, 'min_samples_leaf': 2, 'max_depth': 5}
# - best_estimator_ DecisionTreeRegressor(max_depth=5, min_samples_leaf=2)
# - sMAPE: 7.559511437831738
# - CPU times: user 1min 3s, sys: 16.6 ms, total: 1min 3s
# - Wall time: 1min 3s

# %%
# %%time

model =  DecisionTreeRegressor(max_depth=5, min_samples_leaf=2)
#scores = cross_val_score(model, train_final_features, train_final_target, cv=50, scoring=sMAPE_score)
#print_mean_score(scores*-1)
# Out:
# CPU times: user 24 µs, sys: 14 µs, total: 38 µs
# Wall time: 41.7 µs

# %% [markdown]
# Средняя оценка качества модели: 9.084232145837767

# %% [markdown]
# #### RandomForest

# %%
# %%time

n_estimators = [int(x) for x in np.linspace(start = 20, stop = 100, num = 10)]
max_depth = [int(x) for x in np.linspace(5, 20, num = 5)]
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]
params = { 'n_estimators': n_estimators,
           'max_depth': max_depth,
           'min_samples_split': min_samples_split,
           'min_samples_leaf': min_samples_leaf
         }

#model = get_best_estimator(RandomForestRegressor(), params, sMAPE_score, train_final_features, train_final_target, cv=10)
#print(f'sMAPE: {sMAPE(train_final_target, model.predict(train_final_features))}')
# Out:
# CPU times: user 308 µs, sys: 0 ns, total: 308 µs
# Wall time: 279 µs

# %% [markdown]
# **Результат**
#
# - scorer_: make_scorer(sMAPE, greater_is_better=False)
# - best_score_: 9.189693381060088
# - best_params_: {'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_depth': 5}
# - best_estimator_ RandomForestRegressor(max_depth=5, min_samples_leaf=2, min_samples_split=10)
# - sMAPE: 7.279753016666515
# - CPU times: user 40min 18s, sys: 2.73 s, total: 40min 20s
# - Wall time: 40min 24s

# %%
# %%time

model =  RandomForestRegressor(max_depth=5, min_samples_leaf=2, min_samples_split=10)
#scores = cross_val_score(model, train_final_features, train_final_target, cv=50, scoring=sMAPE_score)
#print_mean_score(scores*-1)
# Out:
# CPU times: user 52 µs, sys: 0 ns, total: 52 µs
# Wall time: 55.3 µs

# %% [markdown]
# - Средняя оценка качества модели: 8.498544178674866
# - CPU times: user 18min 24s, sys: 1.15 s, total: 18min 25s
# - Wall time: 18min 28s

# %% [markdown]
# #### Вывод
#
# Лучшая модель RandomForestRegressor(max_depth=5, min_samples_leaf=2, min_samples_split=10)
#
# Средняя оценка качества модели: 8.498544178674866

# %% [markdown]
# ## Тестовые данные

# %% [markdown]
# ### Dummy

# %%
model_dummy = DummyRegressor()
model_dummy.fit(train_rougher_features, train_rougher_target)
dummy_rougher_predcited = model_dummy.predict(test_rougher_features)
dummy_sMAPE_rougher = sMAPE(test_rougher_target, dummy_rougher_predcited)
print('Dummy sMAPE rougher.output.recovery:', dummy_sMAPE_rougher)
# Out:
# Dummy sMAPE rougher.output.recovery: 6.0945696864139185

# %%
model_dummy = DummyRegressor()
model_dummy.fit(train_final_features, train_final_target)
dummy_final_predcited = model_dummy.predict(test_final_features)
dummy_sMAPE_final = sMAPE(test_final_target, dummy_final_predcited)
print('Dummy sMAPE final.output.recovery:', dummy_sMAPE_final)
# Out:
# Dummy sMAPE final.output.recovery: 9.258819325659797

# %%
final_sMAPE = 0.25 * dummy_sMAPE_rougher + 0.75 * dummy_sMAPE_final
print('Dummy итоговый sMAPE:', final_sMAPE)
# Out:
# Dummy итоговый sMAPE: 8.467756915848327

# %% [markdown]
# ### RandomForestRegressor

# %%
model_rougher = RandomForestRegressor(max_depth=12, min_samples_leaf=4, n_estimators=37)
model_rougher.fit(train_rougher_features, train_rougher_target)
test_rougher_predcited = model_rougher.predict(test_rougher_features)
sMAPE_rougher = sMAPE(test_rougher_target, test_rougher_predcited)

# %%
print('sMAPE rougher.output.recovery:', sMAPE_rougher)
# Out:
# sMAPE rougher.output.recovery: 3.034490443181147

# %%
model_final = RandomForestRegressor(max_depth=5, min_samples_leaf=2, min_samples_split=10)
model_final.fit(train_final_features, train_final_target)
test_final_predicted = model_final.predict(test_final_features)
sMAPE_final = sMAPE(test_final_target, test_final_predicted)

# %%
print('sMAPE final.output.recovery:', sMAPE_final)
# Out:
# sMAPE final.output.recovery: 7.395737638370986

# %%
final_sMAPE = 0.25 * sMAPE_rougher + 0.75 * sMAPE_final
print('Итоговый sMAPE:', final_sMAPE)
# Out:
# Итоговый sMAPE: 6.305425839573527

# %% [markdown]
# ### Вывод
#
# - sMAPE rougher.output.recovery: 3.0822320844011126
# - sMAPE final.output.recovery: 7.39649869327373
# - Итоговый sMAPE: 6.317932041055576

# %% [markdown]
# ## Выводы

# %% [markdown]
# - Загрузили и обработали данные
#     - заполнили пропуски
#     - удалили аномалии
#
#
# - Проверили распределение обучающей и тестовой выборок
#     - распределение совпадает
#
#
# - Проверили правильность расчета целевого параметра
#     - целевое значение рассчитано правильно
#
#
# - Проанализированили концентрацию элементов на каждой стадии
#     - концентрация золота с каждой стадии растет от 8% до 45%
#     - суммарная концентрация металлов так же растет от 20.82% до 59%
#
#
# - Проанализировали размер гранул в обучающей и тестовой выборках
#     - распределение размеров гранул в выборках существенно не отличаются
#
#
# - Написали функцию sMAPE для оценки эффективности моделей
#
#
# - Сравнили разные алгоритмы для обучения модели для промежуточного показателя rougher.output.recovery:
#     - LinearRegression, DescisionTree, RandomForest
#     - лучшая модель - RandomForestRegressor(max_depth=12, min_samples_leaf=4, n_estimators=37)
#     - sMAPE rougher.output.recovery: 3.0822320844011126
#
#
# - Сравнили разные алгоритмы для обучения модели для промежуточного показателя final.output.recovery:
#     - LinearRegression, DescisionTree, RandomForest
#     - лучшая модель - RandomForestRegressor(max_depth=5, min_samples_leaf=2, min_samples_split=10)
#     - sMAPE final.output.recovery: 7.39649869327373
#
#
# - Получили итоговой результат:
#     - Итоговый sMAPE: 6.317932041055576
#
#
# - Проверили модель на адекватность.
#     - модель показывает лучше результаты, чем Dummy
